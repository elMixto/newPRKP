# %%
from matplotlib import pyplot as plt
from ipywidgets import interact

@interact(x=2)
def plot(x):
    plt.plot([i for i in range(100)],[i**x for i in range(100)])
# Out:
# interactive(children=(IntSlider(value=2, description='x', max=6, min=-2), Output()), _dom_classes=('widget-int…

# %%
from matplotlib import pyplot as plt

# %%
from src.solvers.collection import SolverCollection,Instance
instances = [Instance.generate(i,10) for i in range(3,1000,50)]

# %%
x = [instance.n_items for instance in instances]
y = [SolverCollection.baldo_ML(instance).time for instance in instances]
y2 = [SolverCollection.DL(instance).time for instance in instances]
plt.plot(x,y)
