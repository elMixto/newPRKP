# %%
# %load_ext autoreload
# %autoreload 2
from src.data_structures.Instance import Instance
from src.solvers.collection import SolverCollection,SolverConfig,VAR_TYPE
from src.solvers.DLHeu import DLHeu

instance = Instance.from_file("/home/mixto/repositories/newPRKP/data/L_300_171_2557.641.json")
instance = Instance.generate(100,20)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
baldo_sol = SolverCollection.baldo_GA(instance)

# %%
print(instance.evaluate(baldo_sol.sol))
# Out:
# 4055.1285598881964

# %%
a = DLHeu()
a.training_features(instance)
# Out:
# array([[ 8.57800000e+03,  1.10904043e-02,  1.00000000e+00,
#          5.19849247e-02,  2.28323226e-03,  4.33814130e-03,
#          1.00000000e+00],
#        [ 8.57800000e+03,  1.49779999e-02,  1.09197270e-01,
#          7.02075574e-02,  3.03253335e-02,  4.85205336e-02,
#         -0.00000000e+00],
#        [ 8.57800000e+03,  7.39075480e-03,  5.12168892e-01,
#          3.46432665e-02,  1.51138404e-02,  2.87162968e-02,
#          1.00000000e+00],
#        [ 8.57800000e+03,  1.29270760e-02,  3.68641462e-01,
#          6.05941005e-02,  3.14974291e-02,  5.03958866e-02,
#          1.00000000e+00],
#        [ 8.57800000e+03,  1.37991747e-02,  3.22814610e-01,
#          6.46819572e-02,  2.39792087e-02,  4.55604965e-02,
#         -0.00000000e+00],
#        [ 8.57800000e+03,  1.40717629e-02,  1.00000000e+00,
#          6.59596815e-02,  1.53216927e-03,  2.45147082e-03,
#          1.00000000e+00],
#        [ 8.57800000e+03,  8.24217020e-03,  3.34811572e-01,
# ...

# %%
# Out:
# 89
# [[0, 83], [0, 83], [0, 97], [0, 79], [0, 89], [0, 88], [0, 86], [0, 85], [0, 84], [0, 89], [0, 89], [0, 80], [0, 79], [0, 82], [0, 88], [0, 93], [0, 84], [0, 91], [0, 79], [0, 80], [0, 82], [0, 77], [0, 84], [0, 89], [0, 96], [0, 83], [0, 80], [0, 88], [0, 84], [0, 89], [0, 90], [0, 84], [0, 96], [0, 87], [0, 90], [0, 95], [0, 76], [0, 77], [0, 66], [0, 89], [0, 89], [0, 87], [0, 88], [0, 84], [0, 88], [0, 88], [0, 95], [0, 89], [0, 92], [0, 79], [0, 85], [0, 79], [0, 79], [0, 93], [0, 94], [0, 84], [0, 89], [0, 98], [0, 86], [0, 80], [0, 83], [0, 95], [0, 80], [0, 94], [0, 77], [0, 100], [0, 87], [0, 79], [0, 86], [0, 92], [0, 96], [0, 86], [0, 97], [0, 87], [0, 93], [0, 89], [0, 81], [0, 84], [0, 87], [0, 79], [0, 88], [0, 90], [0, 93], [0, 88], [0, 83], [0, 86], [0, 87], [0, 83], [0, 84], [0, 82], [0, 79], [0, 86], [0, 85], [0, 80], [0, 80], [0, 69], [0, 85], [0, 76], [0, 74], [0, 92]]
